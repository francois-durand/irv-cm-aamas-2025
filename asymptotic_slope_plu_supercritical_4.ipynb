# %% [markdown]
# # Asymptotic slopes: Plurality, supercritical regime, $m=4$

# %%
import numpy as np
from matplotlib import pyplot as plt
from plots import *

# %% [markdown]
# All the values used below are taken from the Excel file `Convergence_speed.xlsx`.

# %%
deltas = np.array([0.205, 0.208, 0.212, 0.22, 0.231, 0.249, 0.277, 0.321, 0.39, 0.5]) - 0.2
minus_slopes = np.array([0.0000833045, 0.000151017, 0.000264991, 0.0005754, 0.001147538, 0.002583117, 0.006129117, 0.014968343, 0.035992998, 0.09372783])
errors_on_slopes = np.array([0.000012237, 0.000023115, 0.000032148, 0.000046101, 0.000083203, 0.000129333, 0.001010762, 0.003398475, 0.013089841, 0.018848385])
fit_values = [0.068 * delta**(1.265) for delta in deltas]
fit_str = r'$y = 0.068 x^{1.265}$'
fit_values_2 = [1.022 * delta**(1.999) for delta in deltas]
fit_str_2 = r'$y = 1.022 x^{1.999}$'

# %%
plot_slope_of_delta(deltas=deltas, minus_slopes=minus_slopes, errors_on_slopes=errors_on_slopes, n_c=4, rule_name='Plu',
                    fit_values=fit_values, fit_str=fit_str, fit_values_2=fit_values_2, fit_str_2=fit_str_2)
