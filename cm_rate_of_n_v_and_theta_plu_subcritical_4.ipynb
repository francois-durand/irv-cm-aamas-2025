# %% [markdown]
# # CM rate as a function of $n$: Plurality, subcritical regime, $m=4$

# %%
from compute_cm_rate import *
from plots import *

# %%
compute_cm_rate_of_theta_and_n_v(
    compute_cm_rate=plurality_cm_rate,
    n_vs=[1, 2, 3] + [round(4 * 2**(k/4)) for k in range(0, 33)],
    n_c=4,
    thetas = [round(0.2 - 0.010 * ((0.2 - 0.100) / (0.2 - 0.190))**(k / 9), 3) for k in range(9, -1, -1)], 
    n_samples=1000000
)
# Out:
# run_time_str='5h34m39s'

# %%
my_magic_load(locals())

# %%
plot_ncm_rate_of_n_v_and_theta_subcritical(
    cm_rates=cm_rates, n_vs=n_vs, n_c=n_c, thetas=thetas, n_samples=n_samples, 
    rule_name='Plu', compute_theta_c=plu_theta_c, 
    invert_legend_order=True
)
